# %%
import pickle
import tensorflow
import numpy as np
from numpy.linalg import norm
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input
from sklearn.neighbors import NearestNeighbors
import cv2

# %%
feature_list = np.array(pickle.load(open('embeddings.pkl','rb')))
filenames = pickle.load(open('filenames.pkl','rb'))

# %%
model = ResNet50(weights='imagenet',include_top=False,input_shape=(224,224,3))
model.trainable = False

# %%
model = tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])

# %%
img = image.load_img(r'E:\Art Images dataset\Art_Dataset_Clear\Indian\I (56).jpg',target_size=(224,224))

# %%
img_array = image.img_to_array(img)

# %%
expanded_img_array = np.expand_dims(img_array, axis=0)

# %%
preprocessed_img = preprocess_input(expanded_img_array)

# %%
result = model.predict(preprocessed_img).flatten()

# %%
normalized_result = result / norm(result)

# %%
neighbors = NearestNeighbors(n_neighbors=6,algorithm='brute',metric='euclidean')
neighbors.fit(feature_list)
# Out:
# NearestNeighbors(algorithm='brute', metric='euclidean', n_neighbors=6)

# %%
distances,indices = neighbors.kneighbors([normalized_result])

# %%
distances
# Out:
# array([[5.9604645e-08, 5.2783412e-01, 6.7749113e-01, 6.9325215e-01,
#         6.9984400e-01, 7.0691568e-01]], dtype=float32)

# %%
indices
# Out:
# array([[16532, 11698, 16543, 14647, 16950, 16452]], dtype=int64)

# %%
filenames
# Out:
# ['E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (1).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (100).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (1000).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10000).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10001).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10002).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10003).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10004).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10005).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10006).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10007).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10008).jpg',
#  'E:\\Art Images dataset\\Art_Dataset_Clear\\Foreign\\F (10009).jpg',
# ...

# %%
for file in indices[0][1:6]:
    temp_img = cv2.imread(filenames[file])
    cv2.imshow('output',cv2.resize(temp_img,(512,512)))
    cv2.waitKey(0)

# %%
#saving the neighbours model

# %%
pickle.dump(neighbors,open('neighbourmodel.pkl','wb'))

# %%
nei = pickle.load(open('neighbourmodel.pkl','rb'))

# %%
dis,indi = nei.kneighbors([normalized_result])

# %%
indi
# Out:
# array([[16532, 11698, 16543, 14647, 16950, 16452]], dtype=int64)

# %%
indices
# Out:
# array([[16532, 11698, 16543, 14647, 16950, 16452]], dtype=int64)
